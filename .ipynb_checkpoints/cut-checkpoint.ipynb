# %%
from qiskit.converters import circuit_to_dag, dag_to_circuit
from qiskit.tools.visualization import dag_drawer
from cutting_help_fun import *
import pickle
import networkx as nx

circ = pickle.load(open('results/supremacy_circuit_4_8.dump', 'rb' ))
original_dag = circuit_to_dag(circ)
q = circ.qregs[0]
positions = [(q[2], 1), (q[7], 1), (q[8],3), (q[9],6), (q[10], 4), (q[10],1), (q[14], 1)]
wire, source_node_idx = positions[0]
source_node = list(original_dag.nodes_on_wire(wire=wire, only_ops=True))[source_node_idx]
wire, source_node_idx = positions[1]
sink_node = list(original_dag.nodes_on_wire(wire=wire, only_ops=True))[source_node_idx]

G = original_dag._multi_graph
print(type(G))
# cut_value, partition = nx.minimum_cut(G, source_node, sink_node)
# Out:
# <class 'networkx.classes.multidigraph.MultiDiGraph'>

# %%
import networkx as nx
G = nx.icosahedral_graph()
nx.draw_networkx(G)
print(nx.minimum_edge_cut(G,s=0,t=11))
print(type(G))
# Out:
# {(10, 11), (5, 11), (0, 11), (7, 11), (4, 11)}
