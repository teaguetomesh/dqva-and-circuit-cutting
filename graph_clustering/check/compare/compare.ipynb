# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import networkx as nx
import random
import pprint
from comparison_utils import compare
# Out:
# /usr/lib/python3.4/importlib/_bootstrap.py:321: RuntimeWarning: compiletime version 3.5 of module 'gurobipy' does not match runtime version 3.4
#   return f(*args, **kwds)

# %%
connected = False
while not connected:
    G = nx.gnm_random_graph(13, 20)
    connected = nx.is_connected(G)
nx.draw(G)

# %%
k = 2
gamma = random.random() * 10

# %%
n = len(G.nodes())
constraints = []
for i in range(10):
    first = random.randint(0, n-1)
    second = random.randint(0, n-1)
    if first != second:
        weight = random.random()
        constraints.append([first, second, weight])

pprint.pprint(constraints)
# Out:
# [[4, 6, 0.2491160944798363],
#  [1, 11, 0.23608998796960678],
#  [10, 5, 0.9020831057225935],
#  [6, 1, 0.05863134169191797],
#  [12, 10, 0.6142292652798897],
#  [12, 4, 0.4927024696465845],
#  [2, 5, 0.6709760872560554],
#  [9, 10, 0.3782973923657498],
#  [0, 6, 0.5015368910503992],
#  [5, 9, 0.6476922841169586]]

# %%
compare(G.edges(), constraints, k, gamma)
# Out:
# True
